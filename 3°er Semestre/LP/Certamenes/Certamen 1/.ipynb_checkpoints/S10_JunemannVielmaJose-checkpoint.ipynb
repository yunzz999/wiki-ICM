# %% [markdown]
# # CERTAMEN 1 PROGRAMACIÓN

# %% [markdown]
# NOMBRE ALUMNO: Jose Benjamin Junemann Vielma
#
# MATRÍCULA    : 2024436813
#
# SECCIÓN      : 10
#
# PROFESOR     : Eduardo Méndez O

# %%
'''
Observaciones: Sección exclusiva para el comentarios de él/la revisor/a.

Puntaje : Sección exclusiva para el comentarios de él/la revisor/a.
'''

#  CÓDIGO DEL PROBLEMA 1
def leevalida(n,vmin,vmax,txt):
    while(not vmin <=n<=vmax):
        n=int(input(txt))
    return n

def valorentrada(s):
    if(s=="PACIFICO"):
        return 70000
    elif(s=="ANDES"):
        return 85000
    elif(s=="CANCHAVIP"):
        return 120000
    elif(s=="GALERIA"):
        return 60000
    elif(s=="CANCHAGRAL"):
        return 30000


def main():
    sum=0
    tipo=input("Seleccione el tipo de entrada: ")
    if(tipo=="FIN"):
        return 0
    numero=int(input("Seleccione la cantidad (1,10): "))
    numero=leevalida(numero,1,10,"Datos fuera de rango ingrese denuevo: ")
    while(True):
        sum+=numero*valorentrada(tipo)
        tipo=input("Seleccione el tipo de entrada: ")
        if(tipo=="FIN"):
            return sum
        numero=int(input("Seleccione la cantidad (1,10): "))
        numero=leevalida(numero,1,10,"Datos fuera de rango ingrese denuevo: ")


main()

#quizas validar txt
# Out:
# Seleccione el tipo de entrada:  CANCHAVIP
# Seleccione la cantidad (1,10):  1
# Seleccione el tipo de entrada:  CANCHAGRAL
# Seleccione la cantidad (1,10):  1
# Seleccione el tipo de entrada:  FIN
# 150000

# %%
'''
Observaciones: Sección exclusiva para el comentarios de él/la revisor/a.

Puntaje : Sección exclusiva para el comentarios de él/la revisor/a.
'''

#  CÓDIGO DEL PROBLEMA 2

# %%
'''
Observaciones: Sección exclusiva para el comentarios de él/la revisor/a.

Puntaje : Sección exclusiva para el comentarios de él/la revisor/a.
'''

#  CÓDIGO DEL PROBLEMA 3

def leevalida(n,vmin,vmax,txt):
    while(not vmin <=n<=vmax):
        n=int(input(txt))
    return n



def main():
    E=int(input("Energia: ")
    E=leevalida(E,1,100,"Error en los datos ingrese denuevo: ")
    n=int(input("Ingrese la cantidad de piedras"))

# %%
# Desde esta celda en adelante puedes registrar lo que quieras,
# pruebas, intentos, etc.
